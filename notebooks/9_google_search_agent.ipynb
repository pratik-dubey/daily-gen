# %%
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
from langchain_community.utilities import GoogleSerperAPIWrapper
from langchain_groq import ChatGroq
from langchain.agents import create_agent

# %%
llm = ChatGroq(model="openai/gpt-oss-20b")
search = GoogleSerperAPIWrapper()

# %%
search.run("how many people were laid off by oracle recently ?")
# Out:
# "Oracle Leadership” TD Cowen estimates the cuts hit between 20,000 and 30,000 positions, roughly 18% of Oracle's global workforce of approximately 162,000 people. India was hit hardest, with approximately 12,000 employees terminated out of Oracle's roughly 30,000 person Indian workforce."

# %%
agent = create_agent(
    model=llm,
    tools=[search.run],
    system_prompt="You are a agent and can search for any question on google ."
)

# %%
question = "what is the current conversion value of dollar to inr ?"

res = agent.invoke({"messages":{"role":"user", "content":question}})

# %%
print(res["messages"][-1].content)
# Out:
# **USD → INR (approximate, as of the latest Google search)**
# - **1 USD ≈ 92.75 INR**
#
# *(Exchange rates fluctuate continuously; for the most up‑to‑date figure, check a reliable financial news site or your bank’s currency converter.)*
